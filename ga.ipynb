# %% [markdown]
# <a href="https://colab.research.google.com/github/borobong2/ML/blob/main/ga.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import string

# %% [markdown]
# # Generate Population

# %%
password = 'brad1234'
min_len = 2
max_len = 10
# 엄마도 기억력의 한계가 있어서 비밀번호의 최대, 최소 자릿수를 지정해놓았다

def generate_word(length):
    result = ''
    x = ''.join(random.sample(string.ascii_letters + string.digits, k=length))
    return x

# 옛날 옛적 빵형이 지구에 빛이 있으라하여 첫번째 세대가 태어났다
def generate_population(size, min_len, max_len):
    population = []
    for i in range(size):
        # generate words with balanced length
        length = i % (max_len - min_len + 1) + min_len
        population.append(generate_word(length))
    return population

print(generate_word(length=10))
pop = generate_population(size=100, min_len=min_len, max_len=max_len)
pop
# Out:
# 1shZjCGT8D
# ['W2',
#  'hYz',
#  'WQVT',
#  '4X2Pj',
#  'FLrTR5',
#  '7ROLUsX',
#  'gMJ8nHVD',
#  'bsS8MtBJf',
#  'zZa6Gb9LyS',
#  'B8',
#  'itO',
#  'XH78',
#  'H1M4X',
#  'Rmsenh',
#  'Rfaw8Du',
#  'AyXMBxJH',
#  'oFPilYOI3',
#  'VXbEpltgm7',
#  'SJ',
#  'yYn',
#  'vdAa',
#  'VoJYO',
#  '8FwnSZ',
#  'm5yDOqo',
#  'ngCNqE0P',
#  '7mVoD8Exz',
#  'UBWAJo32Nc',
#  'ex',
#  'zw3',
#  'ev4s',
#  'EVvKa',
#  'jua46W',
#  'el6NJjn',
#  'amYkJRAb',
#  'TBa1clzS0',
#  'dz1HKEf6N5',
#  'l3',
#  '7aV',
#  'O5pT',
#  'DswoF',
#  'jWzkVx',
#  'sBAhzFv',
#  'BhyeJ7xg',
#  'RlwmGvAOY',
#  'D728g5Bx4y',
#  'Ok',
#  'FUY',
#  'vlNi',
#  '4VQiP',
#  'P4On1o',
#  '2FZK3Rg',
#  'IUWjRVt0',
#  'Lyczk6m7q',
#  'we8WgRd0bj',
#  'IJ',
#  '2Ge',
#  'TQsN',
#  'zSF6T',
#  'h5J2mj',
#  'Efb6lSM',
#  'MyxSEWhJ',
#  '7q5NjiYJK',
#  'JkFv6A5PcT',
#  'rY',
#  'zbY',
#  'i3re',
#  'DUqPf',
#  'aQm8z4',
#  'ixdUT6t',
#  'A1UcmVFu',
#  'Ij7kFo2JT',
#  '7yARCfLBgh',
#  'gF',
#  'v1m',
#  'DaOE',
#  '4cLlx',
#  '2viul0',
#  'E5WRT8V',
#  'McSXDdmG',
#  'Z3HCYVs8p',
#  'fTolkQJRPV',
#  '0c',
#  'l0c',
#  'EnYK',
#  'SdQ5X',
#  'N8GxbV',
#  '69uaQrf',
#  'p8BAT29I',
#  'IB6ionRHh',
#  'RwCP9dZL4F',
#  'Vj',
#  'WsF',
#  'iEX1',
#  '6lxhr',
#  '1c8yS0',
#  'up4vKk2',
#  'jI26aMBb',
#  'rzoQAuLhJ',
#  'pHn6sVyOSv',
#  'yI']

# %% [markdown]
# # Fitness Function

# %%
def fitness(password, test_word):
    score = 0

    if len(password) != len(test_word):
        return score
    
    # if fit length, I'll give you score 0.5
    len_score = 0.5
    score += len_score

    for i in range(len(password)):
        if password[i] == test_word[i]:
            score += 1

    # 백점 만점에 몇점?
    return score / (len(password) + len_score) * 100

fitness('abcde', 'abcde')
# Out:
# 100.0

# %% [markdown]
# # Compute Performance and Select Survivors

# %%
def compute_performace(population, password):
    performance_list = []
    for individual in population:
        score = fitness(password, individual)

        # we can predict length of password
        if score > 0:
            pred_len = len(individual)
        performance_list.append([individual, score])

    population_sorted = sorted(performance_list, key=lambda x: x[1], reverse=True)
    return population_sorted, pred_len

def select_survivors(population_sorted, best_sample, lucky_few, password_len):
    next_generation = []

    for i in range(best_sample):
        if population_sorted[i][1] > 0:
            next_generation.append(population_sorted[i][0])

    lucky_survivors = random.sample(population_sorted, k=lucky_few)
    for l in lucky_survivors:
        next_generation.append(l[0])
    
    # generate new population if next_generation is too small
    while len(next_generation) < best_sample + lucky_few:
        next_generation.append(generate_word(length=password_len))

    random.shuffle(next_generation)
    return next_generation

pop_sorted, pred_len = compute_performace(pop, password)
survivors = select_survivors(pop_sorted, best_sample=20, lucky_few=20, password_len=pred_len)

print('Password length must be %s' % pred_len)
survivors
# Out:
# Password length must be 8
# ['yYn',
#  'bsS8MtBJf',
#  'D728g5Bx4y',
#  'GhdqkYEi',
#  'SdQ5X',
#  'IUWjRVt0',
#  'WsF',
#  'AyXMBxJH',
#  'p8BAT29I',
#  '0c',
#  'A1UcmVFu',
#  'DswoF',
#  'jI26aMBb',
#  '4X2Pj',
#  'Efb6lSM',
#  'dPqJYnAH',
#  'jWzkVx',
#  'IJ',
#  'ngCNqE0P',
#  '2FZK3Rg',
#  'JkFv6A5PcT',
#  'McSXDdmG',
#  'nRZXSEu7',
#  'O5pT',
#  'gMJ8nHVD',
#  'EnYK',
#  'MyxSEWhJ',
#  'ngCNqE0P',
#  'PkF0KZ17',
#  'AyXMBxJH',
#  'ctezpJoN',
#  'l0c',
#  'amYkJRAb',
#  'e3aAhLQI',
#  'qxpvnDAC',
#  'H1M4X',
#  'qzROSeTL',
#  'BhyeJ7xg',
#  'Ok',
#  'oM5LrCdK']

# %% [markdown]
# # Create Children

# %%
def create_child(individual1, individual2):
    child = ''
    min_len_ind = min(len(individual1), len(individual2))
    for i in range(min_len_ind):
        if (int(100 * random.random()) < 50):
            child += individual1[i]
        else:
            child += individual2[i]
    return child

# 우리는 그렇게 자비롭지 않기때문에 부모를 내 맘대로 짝지어줄 것이다
def create_children(parents, n_child):
    next_population = []
    for i in range(int(len(parents)/2)):
        for j in range(n_child):
            next_population.append(create_child(parents[i], parents[len(parents) - 1 - i]))
    return next_population

children = create_children(survivors, 5)

children
# Out:
# ['oYn',
#  'oYn',
#  'yY5',
#  'yYn',
#  'oYn',
#  'Os',
#  'Os',
#  'bs',
#  'Ok',
#  'bk',
#  'B728g7xx',
#  'Bh2eJ7xg',
#  'Dh28J7Bg',
#  'B7yeg7xx',
#  'Dh2eJ7Bx',
#  'GhdOSYEL',
#  'GzRqSeEL',
#  'qzdOSeEi',
#  'qzdOkYEi',
#  'GzRqSeTi',
#  'H1M5X',
#  'HdQ4X',
#  'S1M5X',
#  'HdM4X',
#  'S1Q5X',
#  'qUpjnDA0',
#  'qUpjnDAC',
#  'qxWjnVt0',
#  'qUWvRVt0',
#  'qxpvnVA0',
#  'W3F',
#  'esF',
#  'esF',
#  'Wsa',
#  'Wsa',
#  'amXMJRJH',
#  'amYkJRJb',
#  'ayYMBRJH',
#  'amXkBRJb',
#  'amXMBxJH',
#  'l0c',
#  'l0c',
#  'l8B',
#  'p8B',
#  'p8B',
#  'cc',
#  'cc',
#  '0c',
#  '0c',
#  'cc',
#  'AyXMBVJH',
#  'AyUcmxFu',
#  'AyUMmVFH',
#  'AyUMmVFu',
#  'AyUcmVFH',
#  'Pkw0K',
#  'PswoK',
#  'DkFoF',
#  'Pkw0K',
#  'DkwoF',
#  'ng26qMBb',
#  'jIC6aEBP',
#  'ngC6qM0P',
#  'nI2NqM0b',
#  'jgCNaM0P',
#  '4y2PE',
#  'MXxSj',
#  'My2SE',
#  '4y2PE',
#  'My2SE',
#  'EnbK',
#  'Efb6',
#  'Efb6',
#  'EfY6',
#  'EnYK',
#  'dPJ8nnAH',
#  'dMJ8nHAH',
#  'gPJ8nHVD',
#  'gPq8nHAH',
#  'gMqJYnVH',
#  'j5pT',
#  'jWpT',
#  'jWzT',
#  'j5pk',
#  'jWpT',
#  'nR',
#  'IR',
#  'nJ',
#  'nJ',
#  'IR',
#  'ncCXDEmP',
#  'McSXqd0G',
#  'McCNqd0G',
#  'McSNDd0P',
#  'McSXqE0G',
#  'JkZv6Ag',
#  'JFZv6R5',
#  'JkZv6Ag',
#  '2kZv3A5',
#  '2kFK3Rg']

# %% [markdown]
# # Mutation

# %%
def mutate_word(word):
    idx = int(random.random() * len(word))
    if (idx == 0):
        word = random.choice(string.ascii_letters + string.digits) + word[1:]
    else:
        word = word[:idx] + random.choice(string.ascii_letters + string.digits) + word[idx+1:]
    return word

def mutate_population(population, chance_of_mutation):
    for i in range(len(population)):
        if random.random() * 100 < chance_of_mutation:
            population[i] = mutate_word(population[i])
    return population

new_generation = mutate_population(population=children, chance_of_mutation=10)

new_generation
# Out:
# ['vYn',
#  'oYn',
#  'yY5',
#  'yYn',
#  'oYn',
#  'Os',
#  'Os',
#  'bs',
#  'Ok',
#  'bk',
#  'B728g7xx',
#  'Bh2eJ7xg',
#  'Dh28J7Bg',
#  'B7yeg7xx',
#  'Dh2eJ7Bx',
#  'GhdOSYEL',
#  'GzRqSeEL',
#  'qzdOSeEi',
#  'qzdOkYEi',
#  'GzRqSeTi',
#  'H1M5X',
#  'HdQ4X',
#  'S1M5X',
#  'HdM4X',
#  'S1Q5X',
#  'qUpjnDA0',
#  'qUpjnDAC',
#  'qx4jnVt0',
#  'qUWvRVt0',
#  'qxpvnVA0',
#  'W3F',
#  'esF',
#  'esF',
#  'Wsa',
#  'Wsa',
#  'amXMJRJH',
#  'amYkJRJb',
#  'ayYMBRJH',
#  'amXkBRJb',
#  'amXMBxJH',
#  'l0c',
#  'l0c',
#  'l8B',
#  'p8B',
#  'p8B',
#  'cc',
#  'cc',
#  'yc',
#  '0c',
#  'cc',
#  'AyXMBVJH',
#  'AyUcmxFu',
#  'AyUMmVFH',
#  'AyUMmVFu',
#  'AyUcmVFH',
#  'PkR0K',
#  'PswoK',
#  'DkFoF',
#  'Pkw0K',
#  'DkwUF',
#  'ng26qMBb',
#  'jIC6aEBP',
#  'ngC6qM0P',
#  'nI2NqM0b',
#  'jgtNaM0P',
#  '4y2PE',
#  'MXxSj',
#  'My2SE',
#  '4y2PE',
#  'My2SE',
#  'EnbK',
#  'Efb6',
#  'Efb6',
#  'EfY6',
#  'EnYK',
#  'dPJ8nnAH',
#  'dMJ8nHAH',
#  'gPJ8nHVD',
#  'gPq8nHAH',
#  'gMqJYnVH',
#  'j5pT',
#  'jWpT',
#  'jWzT',
#  'j5pk',
#  'jWpT',
#  'nR',
#  'IR',
#  'nJ',
#  'nJ',
#  'IR',
#  'ncCXDEmP',
#  'McSXqd0G',
#  'McCNqd0G',
#  'McSNDd0P',
#  'McSXqE0G',
#  'JkZv6Ag',
#  'JFZv6R5',
#  'HkZv6Ag',
#  '2kZv3A5',
#  '2kFK3Rg']

# %% [markdown]
# # Test

# %%
password = 'BorObOnG'
n_generation = 300
population = 100
best_sample = 20
lucky_few = 20
n_child = 5
chance_of_mutation = 10

pop = generate_population(size=population, min_len=min_len, max_len=max_len)

for g in range(n_generation):
    pop_sorted, pred_len = compute_performace(population=pop, password=password)

    if int(pop_sorted[0][1]) == 100:
        print('SUCCESS! The password is %s' % (pop_sorted[0][0]))
        break
    
    survivors = select_survivors(population_sorted=pop_sorted, best_sample=best_sample, lucky_few=lucky_few, password_len=pred_len)
    
    children = create_children(parents=survivors, n_child=n_child)

    new_generation = mutate_population(population=children, chance_of_mutation=10)
    
    pop = new_generation
    
    print('===== %sth Generation =====' % (g + 1))
    print(pop_sorted[0])
# Out:
# ===== 1th Generation =====
# ['B6Iw2bMk', 17.647058823529413]
# ===== 2th Generation =====
# ['BIQ1X48F', 17.647058823529413]
# ===== 3th Generation =====
# ['LcrVZ9wm', 17.647058823529413]
# ===== 4th Generation =====
# ['BVrwpfdX', 29.411764705882355]
# ===== 5th Generation =====
# ['BcrsUfNX', 29.411764705882355]
# ===== 6th Generation =====
# ['BBrO2Iyz', 41.17647058823529]
# ===== 7th Generation =====
# ['BBrO2fyX', 41.17647058823529]
# ===== 8th Generation =====
# ['BBrOZfyz', 41.17647058823529]
# ===== 9th Generation =====
# ['BBrOZIyz', 41.17647058823529]
# ===== 10th Generation =====
# ['BBrO2IyX', 41.17647058823529]
# ===== 11th Generation =====
# ['BBrOZINH', 41.17647058823529]
# ===== 12th Generation =====
# ['BorO29NH', 52.94117647058824]
# ===== 13th Generation =====
# ['BBrOZynX', 52.94117647058824]
# ===== 14th Generation =====
# ['BBrOZInz', 52.94117647058824]
# ===== 15th Generation =====
# ['BorOZINd', 52.94117647058824]
# ===== 16th Generation =====
# ['BorO2InX', 64.70588235294117]
# ===== 17th Generation =====
# ['BorOZ9nX', 64.70588235294117]
# ===== 18th Generation =====
# ['BorOZInX', 64.70588235294117]
# ===== 19th Generation =====
# ['BorOZInz', 64.70588235294117]
# ===== 20th Generation =====
# ['BorObtnd', 76.47058823529412]
# ===== 21th Generation =====
# ['BorObtnd', 76.47058823529412]
# ===== 22th Generation =====
# ['BorObtnX', 76.47058823529412]
# ===== 23th Generation =====
# ['BorObtnX', 76.47058823529412]
# ===== 24th Generation =====
# ['BorOb9nX', 76.47058823529412]
# ===== 25th Generation =====
# ['BorObInX', 76.47058823529412]
# ===== 26th Generation =====
# ['BorObYnX', 76.47058823529412]
# ===== 27th Generation =====
# ['BorObtnX', 76.47058823529412]
# ===== 28th Generation =====
# ['BorObInd', 76.47058823529412]
# ===== 29th Generation =====
# ['BorObtnX', 76.47058823529412]
# ===== 30th Generation =====
# ['BorObInX', 76.47058823529412]
# ===== 31th Generation =====
# ['BorObInX', 76.47058823529412]
# ===== 32th Generation =====
# ['BorObtnX', 76.47058823529412]
# ===== 33th Generation =====
# ['BorObYnX', 76.47058823529412]
# ===== 34th Generation =====
# ['BorObIn4', 76.47058823529412]
# ===== 35th Generation =====
# ['BorObOnX', 88.23529411764706]
# ===== 36th Generation =====
# ['BorObOnX', 88.23529411764706]
# ===== 37th Generation =====
# ['BorObOnX', 88.23529411764706]
# ===== 38th Generation =====
# ['BorObOnX', 88.23529411764706]
# ===== 39th Generation =====
# ['BorObOnX', 88.23529411764706]
# ===== 40th Generation =====
# ['BorObOnd', 88.23529411764706]
# ===== 41th Generation =====
# ['BorObOnd', 88.23529411764706]
# ===== 42th Generation =====
# ['BorObOnX', 88.23529411764706]
# ===== 43th Generation =====
# ['BorObOnT', 88.23529411764706]
# ===== 44th Generation =====
# ['BorObOnX', 88.23529411764706]
# ===== 45th Generation =====
# ['BorObOnd', 88.23529411764706]
# ===== 46th Generation =====
# ['BorObOnT', 88.23529411764706]
# ===== 47th Generation =====
# ['BorObOnT', 88.23529411764706]
# ===== 48th Generation =====
# ['BorObOnb', 88.23529411764706]
# ===== 49th Generation =====
# ['BorObOnX', 88.23529411764706]
# ===== 50th Generation =====
# ['BorObOnX', 88.23529411764706]
# ===== 51th Generation =====
# ['BorObOnX', 88.23529411764706]
# ===== 52th Generation =====
# ['BorObOnX', 88.23529411764706]
# ===== 53th Generation =====
# ['BorObOnX', 88.23529411764706]
# ===== 54th Generation =====
# ['BorObOnX', 88.23529411764706]
# ===== 55th Generation =====
# ['BorObOnR', 88.23529411764706]
# ===== 56th Generation =====
# ['BorObOnX', 88.23529411764706]
# ===== 57th Generation =====
# ['BorObOnX', 88.23529411764706]
# ===== 58th Generation =====
# ['BorObOnX', 88.23529411764706]
# ===== 59th Generation =====
# ['BorObOnX', 88.23529411764706]
# ===== 60th Generation =====
# ['BorObOnX', 88.23529411764706]
# ===== 61th Generation =====
# ['BorObOnX', 88.23529411764706]
# ===== 62th Generation =====
# ['BorObOnX', 88.23529411764706]
# ===== 63th Generation =====
# ['BorObOnX', 88.23529411764706]
# ===== 64th Generation =====
# ['BorObOnX', 88.23529411764706]
# ===== 65th Generation =====
# ['BorObOnX', 88.23529411764706]
# ===== 66th Generation =====
# ['BorObOnj', 88.23529411764706]
# ===== 67th Generation =====
# ['BorObOnh', 88.23529411764706]
# ===== 68th Generation =====
# ['BorObOnh', 88.23529411764706]
# ===== 69th Generation =====
# ['BorObOnl', 88.23529411764706]
# ===== 70th Generation =====
# ['BorObOnX', 88.23529411764706]
# ===== 71th Generation =====
# ['BorObOnX', 88.23529411764706]
# ===== 72th Generation =====
# ['BorObOnh', 88.23529411764706]
# ===== 73th Generation =====
# ['BorObOnX', 88.23529411764706]
# ===== 74th Generation =====
# ['BorObOnX', 88.23529411764706]
# ===== 75th Generation =====
# ['BorObOnh', 88.23529411764706]
# ===== 76th Generation =====
# ['BorObOnq', 88.23529411764706]
# ===== 77th Generation =====
# ['BorObOnq', 88.23529411764706]
# ===== 78th Generation =====
# ['BorObOnX', 88.23529411764706]
# ===== 79th Generation =====
# ['BorObOnX', 88.23529411764706]
# ===== 80th Generation =====
# ['BorObOnh', 88.23529411764706]
# ===== 81th Generation =====
# ['BorObOnX', 88.23529411764706]
# ===== 82th Generation =====
# ['BorObOnX', 88.23529411764706]
# ===== 83th Generation =====
# ['BorObOnF', 88.23529411764706]
# ===== 84th Generation =====
# ['BorObOnX', 88.23529411764706]
# ===== 85th Generation =====
# ['BorObOnX', 88.23529411764706]
# ===== 86th Generation =====
# ['BorObOnH', 88.23529411764706]
# ===== 87th Generation =====
# ['BorObOnO', 88.23529411764706]
# ===== 88th Generation =====
# ['BorObOnX', 88.23529411764706]
# ===== 89th Generation =====
# ['BorObOnO', 88.23529411764706]
# ===== 90th Generation =====
# ['BorObOnX', 88.23529411764706]
# ===== 91th Generation =====
# ['BorObOnO', 88.23529411764706]
# ===== 92th Generation =====
# ['BorObOnO', 88.23529411764706]
# ===== 93th Generation =====
# ['BorObOnX', 88.23529411764706]
# ===== 94th Generation =====
# ['BorObOnX', 88.23529411764706]
# ===== 95th Generation =====
# ['BorObOn3', 88.23529411764706]
# ===== 96th Generation =====
# ['BorObOni', 88.23529411764706]
# ===== 97th Generation =====
# ['BorObOnX', 88.23529411764706]
# ===== 98th Generation =====
# ['BorObOnX', 88.23529411764706]
# ===== 99th Generation =====
# ['BorObOnX', 88.23529411764706]
# ===== 100th Generation =====
# ['BorObOn3', 88.23529411764706]
# ===== 101th Generation =====
# ['BorObOni', 88.23529411764706]
# ===== 102th Generation =====
# ['BorObOn3', 88.23529411764706]
# ===== 103th Generation =====
# ['BorObOnX', 88.23529411764706]
# ===== 104th Generation =====
# ['BorObOni', 88.23529411764706]
# ===== 105th Generation =====
# ['BorObOnc', 88.23529411764706]
# ===== 106th Generation =====
# ['BorObOni', 88.23529411764706]
# ===== 107th Generation =====
# ['BorObOni', 88.23529411764706]
# ===== 108th Generation =====
# ['BorObOnX', 88.23529411764706]
# ===== 109th Generation =====
# ['BorObOni', 88.23529411764706]
# ===== 110th Generation =====
# ['BorObOn3', 88.23529411764706]
# ===== 111th Generation =====
# ['BorObOn3', 88.23529411764706]
# ===== 112th Generation =====
# ['BorObOnx', 88.23529411764706]
# ===== 113th Generation =====
# ['BorObOnX', 88.23529411764706]
# ===== 114th Generation =====
# ['BorObOni', 88.23529411764706]
# ===== 115th Generation =====
# ['BorObOnx', 88.23529411764706]
# ===== 116th Generation =====
# ['BorObOnx', 88.23529411764706]
# ===== 117th Generation =====
# ['BorObOnx', 88.23529411764706]
# ===== 118th Generation =====
# ['BorObOnX', 88.23529411764706]
# ===== 119th Generation =====
# ['BorObOni', 88.23529411764706]
# ===== 120th Generation =====
# ['BorObOni', 88.23529411764706]
# ===== 121th Generation =====
# ['BorObOni', 88.23529411764706]
# ===== 122th Generation =====
# ['BorObOni', 88.23529411764706]
# ===== 123th Generation =====
# ['BorObOni', 88.23529411764706]
# ===== 124th Generation =====
# ['BorObOni', 88.23529411764706]
# ===== 125th Generation =====
# ['BorObOni', 88.23529411764706]
# ===== 126th Generation =====
# ['BorObOni', 88.23529411764706]
# ===== 127th Generation =====
# ['BorObOni', 88.23529411764706]
# ===== 128th Generation =====
# ['BorObOni', 88.23529411764706]
# ===== 129th Generation =====
# ['BorObOni', 88.23529411764706]
# ===== 130th Generation =====
# ['BorObOni', 88.23529411764706]
# ===== 131th Generation =====
# ['BorObOnx', 88.23529411764706]
# ===== 132th Generation =====
# ['BorObOni', 88.23529411764706]
# ===== 133th Generation =====
# ['BorObOni', 88.23529411764706]
# SUCCESS! The password is BorObOnG
